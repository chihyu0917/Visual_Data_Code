# %%
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['agg.path.chunksize'] = 10000
plt.rcParams['font.sans-serif'] = ['Arial Unicode MS']

# %%
path = '/Users/siowanchoi/Desktop/PROJECT/201801/vdtrafonetab_info_001.csv'
df = pd.read_csv( path , header= None)
print(df)
# Out:
#                0   1          2         3        4         5   6   7     8   \
# 0         VL7PX00   1  121.55778  25.04898  600083A      光復北路   6   3   2.0
# 1         VN0E0E2   0  121.52781  25.06761   200080    新生高架道路   2   0  11.0
# 2         VN0E0E2   0  121.52781  25.06761   200080    新生高架道路   2   1  10.0
# 3         V2RTQ20   1  121.57447  24.99505  600409A     新光路一段   6   0   0.0
# 4         V2RTQ20   1  121.57447  24.99505  600409A     新光路一段   6   1   0.0
# ...           ...  ..        ...       ...      ...       ...  ..  ..   ...
# 23737993  V1030A0   0  121.53758  25.03905   200040  建國南北快速道路   2   2   0.0
# 23737994  VIAM700   0  121.54359  25.03672  600321A    復興南路一段   6   0   0.0
# 23737995  VIAM700   0  121.54359  25.03672  600321A    復興南路一段   6   1   5.0
# 23737996  VIAM700   0  121.54359  25.03672  600321A    復興南路一段   6   2   2.0
# 23737997  V6160C1   0  121.59120  25.06071   200090      環東大道   2   0   0.0
#
#              9   ...    15    16    17  18  19  20  21  22  \
# 0          14.0  ...  24.0  60.0   0.0   1   1  往南   4  60
# 1          83.0  ...   7.0  60.0   0.0   0   0  往南   4  60
# 2         107.0  ...   5.0  60.0   0.0   0   0  往南   4  60
# 3           0.0  ...   5.0  60.0   0.0   0   0  往西   6  60
# 4           0.0  ...   4.0  60.0   0.0   0   0  往西   6  60
# ...         ...  ...   ...   ...   ...  ..  ..  ..  ..  ..
# 23737993    0.0  ...  11.0  60.0   0.0   0   0  往南   4  60
# 23737994    0.0  ...   1.0  60.0  79.0   0   0  往南   4  60
# 23737995   33.0  ...  11.0  60.0  35.0   0   0  往南   4  60
# 23737996   30.0  ...  10.0  60.0  49.0   0   0  往南   4  60
# 23737997    0.0  ...   3.0  60.0  66.0   0   0  往東   0  60
#
#                            23          24
# 0         2018-01-10 08:29:00  2018-01-10
# 1         2018-01-10 08:29:00  2018-01-10
# 2         2018-01-10 08:29:00  2018-01-10
# 3         2018-01-10 08:29:00  2018-01-10
# 4         2018-01-10 08:29:00  2018-01-10
# ...                       ...         ...
# 23737993  2018-01-25 16:50:00  2018-01-25
# 23737994  2018-01-25 16:50:00  2018-01-25
# 23737995  2018-01-25 16:50:00  2018-01-25
# 23737996  2018-01-25 16:50:00  2018-01-25
# 23737997  2018-01-25 16:50:00  2018-01-25
#
# [23737998 rows x 25 columns]

# %%
RoadID = df[4] #道路路名碼
RoadName = df[5] #道路名稱
BIGVOLUME = df[8] #大車的流量
BIGSPEED = df[9] #大車的速率
CARVOLUME = df[10] #汽車的流量
CARSPEED = df[11] #汽車的速率
MOTORVOLUME = df[12] #機車的流量
MOTORSPEED = df[13] #機車的速率
FREESPD = df[22] #速限

# %%
fig = plt.figure(figsize=(50,9))
plt.plot(RoadName, CARVOLUME)
plt.tick_params(axis='x', labelsize=8)
plt.xticks(rotation=-20) 
plt.xlabel("道路名稱")
plt.ylabel("流量") 
plt.title("2018年1月汽車流量")
plt.grid(True)
